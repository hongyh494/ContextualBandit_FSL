# %% [markdown]
# # 单臂老虎机，在假定F(p)的回报相同时
# 1. 其中，$p$为触发老虎机赢钱的概率，$ \mu $应为触发赢钱的时候的平均回报，J为连续输钱J次后的J奖励，因此大样本下的单次摇一个老虎机的回报是
# $$ F(p) = \mu * p + J * p_j \\ p_j = p\frac{(1-p)^j}{1-(1-p)^j} $$
#
# 2. 不同的J下，Casino在单臂下有个最小的p值s.t.每一把能贪到的money最多，但这个给出来以后顾客都知道

# %% [markdown]
# ### mu = 0.4

# %%
import numpy as np

# F(p) = \mu * p + J * p_j

# numerator =  p * (1 - p)**(J)
# denominator = 1 - (1 - p)**(J)
# p_j = numerator / denominator
# asymptotic_mu_star = mu*p + J*p_j 
import matplotlib.pyplot as plt

# Given values for mu
mu = 1
mu = 0.4

# Generate a range of p values
p_values = np.linspace(0.01, 0.99, 100)

# Different values for J
J_values = [3, 4, 5, 6, 7]

# Plot the values for different J
for J in J_values:
    asymptotic_mu_star_values = []
    for p in p_values:
        numerator = p * (1 - p)**J
        denominator = 1 - (1 - p)**J
        p_j = numerator / denominator
        asymptotic_mu_star = mu * p + J * p_j
        asymptotic_mu_star_values.append(asymptotic_mu_star)
    plt.plot(p_values, asymptotic_mu_star_values, label=f'J={J}')

plt.xlabel('p')
plt.ylabel('Asymptotic Mu Star')
plt.title('Asymptotic Mu Star vs p for different J')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### mu = 1

# %%
import numpy as np

# F(p) = \mu * p + J * p_j

# numerator =  p * (1 - p)**(J)
# denominator = 1 - (1 - p)**(J)
# p_j = numerator / denominator
# asymptotic_mu_star = mu*p + J*p_j 
import matplotlib.pyplot as plt

# Given values for mu
mu = 1

# Generate a range of p values
p_values = np.linspace(0.01, 0.99, 100)

# Different values for J
J_values = [3, 4, 5, 6, 7]

# Plot the values for different J
for J in J_values:
    asymptotic_mu_star_values = []
    for p in p_values:
        numerator = p * (1 - p)**J
        denominator = 1 - (1 - p)**J
        p_j = numerator / denominator
        asymptotic_mu_star = mu * p + J * p_j
        asymptotic_mu_star_values.append(asymptotic_mu_star)
    plt.plot(p_values, asymptotic_mu_star_values, label=f'J={J}')

plt.xlabel('p')
plt.ylabel('Asymptotic Mu Star')
plt.title('Asymptotic Mu Star vs p for different J')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### mu = 1.4

# %%
import numpy as np

# F(p) = \mu * p + J * p_j

# numerator =  p * (1 - p)**(J)
# denominator = 1 - (1 - p)**(J)
# p_j = numerator / denominator
# asymptotic_mu_star = mu*p + J*p_j 
import matplotlib.pyplot as plt

# Given values for mu
# mu = 2 # =2 是stationry 里面用的
mu = 1

# Generate a range of p values
p_values = np.linspace(0.01, 0.99, 100)

# Different values for J
J_values = [3, 4, 5, 6, 7]

# Plot the values for different J
for J in J_values:
    asymptotic_mu_star_values = []
    for p in p_values:
        numerator = p * (1 - p)**J
        denominator = 1 - (1 - p)**J
        p_j = numerator / denominator
        asymptotic_mu_star = mu * p + J * p_j
        asymptotic_mu_star_values.append(asymptotic_mu_star)
    plt.plot(p_values, asymptotic_mu_star_values, label=f'J={J}')

plt.xlabel('p')
plt.ylabel('Asymptotic Mu Star')
plt.title('Asymptotic Mu Star vs p for different J')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 探究J变动的时候未来奖励的变化

# %%
import numpy as np

# F(p) = \mu * p + J * p_j

# numerator =  p * (1 - p)**(J)
# denominator = 1 - (1 - p)**(J)
# p_j = numerator / denominator
# asymptotic_mu_star = mu*p + J*p_j 
import matplotlib.pyplot as plt

# Given values for mu
mu = 1

# Generate a range of p values
p_values = np.linspace(0.01, 0.99, 100)

# Different values for J
J_values = [3, 4, 5, 6, 7]

# Plot the values for different J
for J in J_values:
    asymptotic_mu_star_values = []
    for p in p_values:
        numerator = p * (1 - p)**J
        denominator = 1 - (1 - p)**J
        p_j = numerator / denominator
        asymptotic_mu_star =  p_j
        # asymptotic_mu_star =  J * p_j
        asymptotic_mu_star_values.append(asymptotic_mu_star)
    plt.plot(p_values, asymptotic_mu_star_values, label=f'J={J}')

plt.xlabel('p')
plt.ylabel('Asymptotic Mu Star')
plt.title('J given vs p for different J')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np

# F(p) = \mu * p + J * p_j

# numerator =  p * (1 - p)**(J)
# denominator = 1 - (1 - p)**(J)
# p_j = numerator / denominator
# asymptotic_mu_star = mu*p + J*p_j 
import matplotlib.pyplot as plt

# Given values for mu
mu = 1

# Generate a range of p values
p_values = np.linspace(0.01, 0.99, 100)

# Different values for J
J_values = [3, 4, 5, 6, 7]

# Plot the values for different J
for J in J_values:
    asymptotic_mu_star_values = []
    for p in p_values:
        fp = (1-p) * (1-(1-p)**J) - J * p 
        # asymptotic_mu_star =  J * p_j
        asymptotic_mu_star_values.append(fp)
    plt.plot(p_values, asymptotic_mu_star_values, label=f'J={J}')

plt.xlabel('p')
plt.ylabel('Asymptotic Mu Star')
plt.title('f\'(p) given vs p for different J')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 决定搞两个手臂，mean payout最大的那个作为好东西
